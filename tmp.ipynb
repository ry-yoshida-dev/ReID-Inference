# %%
# !uv pip install -r requirements.txt
# Out:
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#     Updated https://github.com/ry-yoshida-private/TorchModules.git (fcc0efa3c9c7
# Resolved 42 packages in 1.76s
#    Updating https://github.com/ry-yoshida-dev/TransReID-SSL.git (HEAD)
#    Updating https://github.com/ry-yoshida-dev/TransReID-SSL.git (HEAD)
#    Updating https://github.com/ry-yoshida-dev/TransReID-SSL.git (HEAD)
#    Updating https://github.com/ry-yoshida-dev/TransReID-SSL.git (HEAD)
#    Updating https://github.com/ry-yoshida-dev/TransReID-SSL.git (HEAD)
#    Updating https://github.com/ry-yoshida-dev/TransReID-SSL.git (HEAD)
#     Updated https://github.com/ry-yoshida-dev/TransReID-SSL.git (4a23cbbe5aa12bf
# ...

# %%
# !uv pip install -e.
# Out:
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#    Updating https://github.com/ry-yoshida-private/TorchModules.git (HEAD)
#     Updated https://github.com/ry-yoshida-private/TorchModules.git (fcc0efa3c9c7
# Resolved 43 packages in 606ms
#    Building reid-inference @ file:///Users/ry-yoshida/Desktop/Python/ReID-Infere
#    Building reid-inference @ file:///Users/ry-yoshida/Desktop/Python/ReID-Infere
#       Built reid-inference @ file:///Users/ry-yoshida/Desktop/Python/ReID-Infere
# Prepared 1 package in 347ms
# Uninstalled 1 package in 1ms
# Installed 1 package in 1ms.0 (from file:///Users/ry-yoshida/
#  ~ reid-inference==0.1.0 (from file:///Users/ry-yoshida/Desktop/Python/ReID-Inference)

# %%
# !python3 -m reid.model.torchreid.model \
  --weights osnet_ain_ms_d_c.pth \
  --images-dir image \
  --output-dir result
# Out:
# /Users/ry-yoshida/Desktop/Python/ReID-Inference/.venv/lib/python3.13/site-packages/torch_modules/inference_manager.py:31: UserWarning: TorchInferenceManager disables float16 on CPU and uses float32 instead.
#   warnings.warn(
# INFO reid.model.torchreid.model: osnet_ain_x1_0 from packaged Torchreid is adopted as the ReID model.
# Successfully loaded pretrained weights from "/Users/ry-yoshida/Desktop/Python/ReID-Inference/osnet_ain_ms_d_c.pth"
# INFO root: Wrote 1 feature files under result

# %%
# !python3 -m reid.model.fastreid.model \
  --weights mot17_sbs_S50.pth \
  --model-name sbs_S50 \
  --images-dir image \
  --output-dir result
# Out:
# /Users/ry-yoshida/Desktop/Python/ReID-Inference/.venv/lib/python3.13/site-packages/torch_modules/inference_manager.py:31: UserWarning: TorchInferenceManager disables float16 on CPU and uses float32 instead.
#   warnings.warn(
# INFO reid.model.fastreid.model: sbs_S50 from packaged FastReID is adopted as the ReID model.
# INFO fast_reid.fastreid.utils.checkpoint: Loading checkpoint from /Users/ry-yoshida/Desktop/Python/ReID-Inference/mot17_sbs_S50.pth
# WARNING fast_reid.fastreid.utils.checkpoint: Skip loading parameter 'heads.weight' to the model due to incompatible shapes: (487, 2048) in the checkpoint but (0, 2048) in the model! You might want to double check if this is expected.
# INFO fast_reid.fastreid.utils.checkpoint: Some model parameters or buffers are not found in the checkpoint:
#   heads.weight
# INFO root: Wrote 1 feature files under result

# %%
import numpy as np
feature = np.load("result/tmp_pose_test.npy")
print(feature.shape)
# Out:
# (384,)

# %%
# %%bash
# PYTHONPATH=src python3 -m reid.model.torchreid.model \
#   --weights weights/osnet_ain_ms_d_c.pth \
#   --images-dir image \
#   --output-dir result
# Out:
# /Users/ry-yoshida/Desktop/Python/ReID-Inference/.venv/lib/python3.13/site-packages/torch_modules/inference_manager.py:31: UserWarning: TorchInferenceManager disables float16 on CPU and uses float32 instead.
#   warnings.warn(
# INFO reid.model.torchreid.model: osnet_ain_x1_0 from Torchreid is adopted as the ReID model.
# /Users/ry-yoshida/Desktop/Python/ReID-Inference/src/reid/external/deep-person-reid/torchreid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# Successfully loaded pretrained weights from "/Users/ry-yoshida/Desktop/Python/ReID-Inference/weights/osnet_ain_ms_d_c.pth"
# INFO root: Wrote 1 feature files under result

# %%
# %%bash
# PYTHONPATH=src python3 -m reid.model.fastreid.model \
#   --weights weights/mot17_sbs_S50.pth \
#   --images-dir image \
#   --output-dir result
# Out:
# /Users/ry-yoshida/Desktop/Python/ReID-Inference/.venv/lib/python3.13/site-packages/torch_modules/inference_manager.py:31: UserWarning: TorchInferenceManager disables float16 on CPU and uses float32 instead.
#   warnings.warn(
# INFO reid.model.fastreid.model: sbs_S50 from fast-reid is adopted as the ReID model.
# INFO root: Wrote 1 feature files under result

# %%
# %%bash
# PYTHONPATH=src python3 -m reid.model.transreid.model \
#   --weights weights/vit_small_cfs_lup.pth \
#   --images-dir image \
#   --output-dir result
# Out:
# /Users/ry-yoshida/Desktop/Python/ReID-Inference/.venv/lib/python3.13/site-packages/torch_modules/inference_manager.py:31: UserWarning: TorchInferenceManager disables float16 on CPU and uses float32 instead.
#   warnings.warn(
# INFO reid.model.transreid.model: Using model_name: vit_small_patch16_224_TransReID as backbone
# using stride: [16, 16], and patch number is num_y16 * num_x8
# Load 150 / 152 layers.
# INFO reid.model.transreid.model: Loaded weights from /Users/ry-yoshida/Desktop/Python/ReID-Inference/weights/vit_small_cfs_lup.pth
# INFO root: Wrote 1 feature files under result
